# %% [markdown]
# # OpenCreator Personal Burmese Dubbing MVP
#
# Upload the `opencreator-kaggle-dubbing` folder to `/kaggle/working/`, then run the cells below. The app is for temporary personal use while this Kaggle session remains alive.

# %%
from pathlib import Path
APP_DIR = Path('/kaggle/working/opencreator-kaggle-dubbing')
assert (APP_DIR / 'app.py').exists(), 'Upload/extract the project folder first.'
# %cd $APP_DIR

# %%
# !apt-get update -qq && apt-get install -y -qq ffmpeg fonts-noto-core fonts-noto-extra
# !pip install -q -r requirements.txt

# %%
# Optional translation fallback. Keep keys in Kaggle Secrets for personal use.
import os
# os.environ['GEMINI_API_KEY'] = 'paste-key-here'
# os.environ['GROQ_API_KEY'] = 'paste-key-here'
print('Set GEMINI_API_KEY or GROQ_API_KEY before launching if you want cloud translation fallback.')

# %%
# !python app.py
